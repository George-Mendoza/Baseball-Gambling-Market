# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
game_odds = pd.read_csv(r'C:\\Users\\mendo\\Desktop\\game_odds.csv', sep=',', header=0, low_memory=False, index_col=0)
pitch_summary = pd.read_csv(r'C:\\Users\\mendo\\Desktop\\pitch_summary.csv', sep=',', header=0, low_memory=False, index_col=0)
batter_summary = pd.read_csv(r'C:\\Users\\mendo\\Desktop\\batter_summary.csv', sep=',', header=0, low_memory=False, index_col=0)

# %%
team_games = pitch_summary.merge(batter_summary, how='left', 
                                   left_on=['game_id', 'fielding_team_id'], 
                                   right_on=['bat_game_id', 'bat_batting_team_id'])

# %%
team_games = team_games[['date', 'game_id', 'fielding_team_id', 's_pitcher',
       's_pitcher_hand', 's_starter', 's_earned_runs','s_groundball',
       's_flyball', 's_popup', 's_linedrive', 's_errors',
       's_balls', 's_called_balls', 's_int_balls', 's_pitchout',
       's_hit_batter', 's_other_balls', 's_strikes', 's_called_strikes',
       's_swinging_strike', 's_foul_strike', 's_other_strikes',
       's_unknown', 's_none', 's_generic_out', 's_strikeout',
       's_stolen_base', 's_defensive_indifference', 's_caught_stealing',
       's_pickoff_error', 's_pickoff', 's_wild_pitch', 's_passed_ball',
       's_balk', 's_out_advancing', 's_foul_error', 's_walk',
       's_intentional_walk', 's_hit_by_pitch', 's_interference', 's_error',
       's_fielders_choice', 's_single', 's_double', 's_triple',
       's_home_run', 's_missing_play', 's_outs', 's_sac_fly', 's_sac_hit', 's_ab',
       'b_earned_runs','b_groundball', 'b_flyball',
       'b_popup', 'b_linedrive', 'b_errors', 'b_balls',
       'b_called_balls', 'b_int_balls', 'b_pitchout', 'b_hit_batter',
       'b_other_balls', 'b_strikes', 'b_called_strikes',
       'b_swinging_strike', 'b_foul_strike', 'b_other_strikes',
       'b_unknown', 'b_none', 'b_generic_out', 'b_strikeout',
       'b_stolen_base', 'b_defensive_indifference', 'b_caught_stealing',
       'b_pickoff_error', 'b_pickoff', 'b_wild_pitch', 'b_passed_ball',
       'b_balk', 'b_out_advancing', 'b_foul_error', 'b_walk',
       'b_intentional_walk', 'b_hit_by_pitch', 'b_interference', 'b_error',
       'b_fielders_choice', 'b_single', 'b_double', 'b_triple',
       'b_home_run', 'b_missing_play', 'b_outs', 'b_sac_fly', 'b_sac_hit', 'b_ab', 
       'bat_balls_in_plate_app', 'bat_called_balls_plate_app',
       'bat_int_balls_plate_app', 'bat_pitchout_plate_app',
       'bat_hit_batter_plate_app', 'bat_other_balls_plate_app',
       'bat_strikes_in_plate_app', 'bat_called_strikes_plate_app',
       'bat_swinging_strike_plate_app', 'bat_foul_strike_plate_app',
       'bat_other_strikes_plate_app', 'bat_runs_on_play', 'bat_unknown',
       'bat_none', 'bat_generic_out', 'bat_strikeout', 'bat_stolen_base',
       'bat_defensive_indifference', 'bat_caught_stealing',
       'bat_pickoff_error', 'bat_pickoff', 'bat_wild_pitch',
       'bat_passed_ball', 'bat_balk', 'bat_out_advancing',
       'bat_foul_error', 'bat_walk', 'bat_intentional_walk',
       'bat_hit_by_pitch', 'bat_interference', 'bat_error',
       'bat_fielders_choice', 'bat_single', 'bat_double', 'bat_triple',
       'bat_home_run', 'bat_missing_play', 'bat_groundball', 'bat_flyball',
       'bat_popup', 'bat_linedrive', 'bat_batter_scored', 'bat_sac_fly', 'bat_sac_hit', 'bat_ab']]

team_games.columns = ['date', 'game_id', 'team_id', 's_pitcher',
       's_pitcher_hand', 's_starter', 's_earned_runs','s_groundball',
       's_flyball', 's_popup', 's_linedrive', 's_errors',
       's_balls', 's_called_balls', 's_int_balls', 's_pitchout',
       's_hit_batter', 's_other_balls', 's_strikes', 's_called_strikes',
       's_swinging_strike', 's_foul_strike', 's_other_strikes',
       's_unknown', 's_none', 's_generic_out', 's_strikeout',
       's_stolen_base', 's_defensive_indifference', 's_caught_stealing',
       's_pickoff_error', 's_pickoff', 's_wild_pitch', 's_passed_ball',
       's_balk', 's_out_advancing', 's_foul_error', 's_walk',
       's_intentional_walk', 's_hit_by_pitch', 's_interference', 's_error',
       's_fielders_choice', 's_single', 's_double', 's_triple',
       's_home_run', 's_missing_play', 's_outs', 's_sac_fly', 's_sac_hit', 's_ab',
       'b_earned_runs','b_groundball', 'b_flyball',
       'b_popup', 'b_linedrive', 'b_errors', 'b_balls',
       'b_called_balls', 'b_int_balls', 'b_pitchout', 'b_hit_batter',
       'b_other_balls', 'b_strikes', 'b_called_strikes',
       'b_swinging_strike', 'b_foul_strike', 'b_other_strikes',
       'b_unknown', 'b_none', 'b_generic_out', 'b_strikeout',
       'b_stolen_base', 'b_defensive_indifference', 'b_caught_stealing',
       'b_pickoff_error', 'b_pickoff', 'b_wild_pitch', 'b_passed_ball',
       'b_balk', 'b_out_advancing', 'b_foul_error', 'b_walk',
       'b_intentional_walk', 'b_hit_by_pitch', 'b_interference', 'b_error',
       'b_fielders_choice', 'b_single', 'b_double', 'b_triple',
       'b_home_run', 'b_missing_play', 'b_outs',  'b_sac_fly', 'b_sac_hit', 'b_ab',
       'bat_balls_in_plate_app', 'bat_called_balls_plate_app',
       'bat_int_balls_plate_app', 'bat_pitchout_plate_app',
       'bat_hit_batter_plate_app', 'bat_other_balls_plate_app',
       'bat_strikes_in_plate_app', 'bat_called_strikes_plate_app',
       'bat_swinging_strike_plate_app', 'bat_foul_strike_plate_app',
       'bat_other_strikes_plate_app', 'bat_runs_on_play', 'bat_unknown',
       'bat_none', 'bat_generic_out', 'bat_strikeout', 'bat_stolen_base',
       'bat_defensive_indifference', 'bat_caught_stealing',
       'bat_pickoff_error', 'bat_pickoff', 'bat_wild_pitch',
       'bat_passed_ball', 'bat_balk', 'bat_out_advancing',
       'bat_foul_error', 'bat_walk', 'bat_intentional_walk',
       'bat_hit_by_pitch', 'bat_interference', 'bat_error',
       'bat_fielders_choice', 'bat_single', 'bat_double', 'bat_triple',
       'bat_home_run', 'bat_missing_play', 'bat_groundball', 'bat_flyball',
       'bat_popup', 'bat_linedrive', 'bat_batter_scored', 'bat_sac_fly', 'bat_sac_hit', 'bat_ab']

team_games.fillna(0)

team_games['season'] = team_games['date'].str[:4]
team_games['team_season'] = team_games['team_id'] + team_games['season']
team_games['pitcher_season'] = team_games['s_pitcher'] + team_games['season']

team_games['games'] = 1
team_games['games_played'] = team_games.groupby('team_season')['games'].cumsum() - 1
team_games['s_pitcher_games'] = team_games.groupby('s_pitcher')['games'].cumsum() - 1

team_games['bat_outs'] = team_games['bat_generic_out'] + team_games['bat_strikeout'] + team_games['bat_caught_stealing'] + team_games['bat_pickoff']

# %%
team_games
# Out:
#              date       game_id team_id s_pitcher s_pitcher_hand s_starter  \
# 0      2007-04-01  SLN200704010     NYN  glavt001              L         T
# 1      2007-04-01  SLN200704010     SLN  carpc002              R         T
# 2      2007-04-02  ANA200704020     ANA  lackj001              R         T
# 3      2007-04-02  ANA200704020     TEX  millk004              R         T
# 4      2007-04-02  CHA200704020     CHA  contj002              R         T
# 5      2007-04-02  CHA200704020     CLE  sabac001              L         T
# 6      2007-04-02  CIN200704020     CHN  zambc001              R         T
# 7      2007-04-02  CIN200704020     CIN  haraa001              R         T
# 8      2007-04-02  COL200704020     ARI  webbb001              R         T
# 9      2007-04-02  COL200704020     COL  cooka002              R         T
# 10     2007-04-02  DET200704020     DET  bondj001              R         T
# ...

# %%
# how a team got on base
team_games['bat_walk_c'] = team_games.groupby('team_season')['bat_walk'].cumsum() - team_games['bat_walk']
team_games['bat_walk_a'] = team_games['bat_walk_c'] / team_games['games_played']

team_games['bat_hit_by_pitch_c'] = team_games.groupby('team_season')['bat_hit_by_pitch'].cumsum() - team_games['bat_hit_by_pitch']
team_games['bat_hit_by_pitch_a'] = team_games['bat_hit_by_pitch_c'] / team_games['games_played']

team_games['bat_outs_c'] = team_games.groupby('team_season')['bat_outs'].cumsum() - team_games['bat_outs']
team_games['bat_outs_a'] = team_games['bat_outs_c'] / team_games['games_played']

team_games['bat_strikeout_c'] = team_games.groupby('team_season')['bat_strikeout'].cumsum() - team_games['bat_strikeout']
team_games['bat_strikeout_a'] = team_games['bat_strikeout_c'] / team_games['games_played']

team_games['bat_intentional_walk_c'] = team_games.groupby('team_season')['bat_intentional_walk'].cumsum() - team_games['bat_intentional_walk']
team_games['bat_intentional_walk_a'] = team_games['bat_intentional_walk_c'] / team_games['games_played']

team_games['bat_single_c'] = team_games.groupby('team_season')['bat_single'].cumsum() - team_games['bat_single']
team_games['bat_single_a'] = team_games['bat_single_c'] / team_games['games_played']

team_games['bat_double_c'] = team_games.groupby('team_season')['bat_double'].cumsum() - team_games['bat_double']
team_games['bat_double_a'] = team_games['bat_double_c'] / team_games['games_played']

team_games['bat_triple_c'] = team_games.groupby('team_season')['bat_triple'].cumsum() - team_games['bat_triple']
team_games['bat_triple_a'] = team_games['bat_triple_c'] / team_games['games_played']

team_games['bat_hr_c'] = team_games.groupby('team_season')['bat_home_run'].cumsum() - team_games['bat_home_run']
team_games['bat_hr_a'] = team_games['bat_hr_c'] / team_games['games_played']

team_games['bat_sac_fly_c'] = team_games.groupby('team_season')['bat_sac_fly'].cumsum() - team_games['bat_sac_fly']
team_games['bat_sac_fly_a'] = team_games['bat_sac_fly_c'] / team_games['games_played']

team_games['bat_sac_hit_c'] = team_games.groupby('team_season')['bat_sac_hit'].cumsum() - team_games['bat_sac_hit']
team_games['bat_sac_hit_a'] = team_games['bat_sac_hit_c'] / team_games['games_played']

team_games['bat_ab_c'] = team_games.groupby('team_season')['bat_ab'].cumsum() - team_games['bat_ab']
team_games['bat_ab_a'] = team_games['bat_ab_c'] / team_games['games_played']

team_games['bat_hits_c'] = team_games['bat_single_c'] + team_games['bat_double_c'] + team_games['bat_triple_c'] + team_games['bat_hr_c']
team_games['bat_hits_a'] = team_games['bat_hits_c'] / team_games['games_played']


# the type of contact a team is making
team_games['bat_gb_c'] = team_games.groupby('team_season')['bat_groundball'].cumsum() - team_games['bat_groundball']
team_games['bat_gb_a'] = team_games['bat_gb_c'] / team_games['games_played']

team_games['bat_fb_c'] = team_games.groupby('team_season')['bat_flyball'].cumsum() - team_games['bat_flyball']
team_games['bat_fb_a'] = team_games['bat_fb_c'] / team_games['games_played']

team_games['bat_pop_c'] = team_games.groupby('team_season')['bat_popup'].cumsum() - team_games['bat_popup']
team_games['bat_pop_a'] = team_games['bat_pop_c'] / team_games['games_played']

team_games['bat_ld_c'] = team_games.groupby('team_season')['bat_linedrive'].cumsum() - team_games['bat_linedrive']
team_games['bat_ld_a'] = team_games['bat_ld_c'] / team_games['games_played']

# how the team is seeing the ball
team_games['bat_balls_c'] = team_games.groupby('team_season')['bat_balls_in_plate_app'].cumsum() - team_games['bat_balls_in_plate_app']
team_games['bat_balls_a'] = team_games['bat_balls_c'] / team_games['games_played']

team_games['bat_strikes_c'] = team_games.groupby('team_season')['bat_strikes_in_plate_app'].cumsum() - team_games['bat_strikes_in_plate_app']
team_games['bat_strikes_a'] = team_games['bat_strikes_c'] / team_games['games_played']

team_games['bat_called_strikes_c'] = team_games.groupby('team_season')['bat_called_strikes_plate_app'].cumsum() - team_games['bat_called_strikes_plate_app']
team_games['bat_called_strikes_a'] = team_games['bat_called_strikes_c'] / team_games['games_played']

team_games['bat_swinging_strikes_c'] = team_games.groupby('team_season')['bat_swinging_strike_plate_app'].cumsum() - team_games['bat_swinging_strike_plate_app']
team_games['bat_swinging_strikes_a'] = team_games['bat_swinging_strikes_c'] / team_games['games_played']


# how a starting pitcher lets teams on base
team_games['s_walk_c'] = team_games.groupby('pitcher_season')['s_walk'].cumsum() - team_games['s_walk']
team_games['s_walk_a'] = team_games['s_walk_c'] / team_games['s_pitcher_games']

team_games['s_hit_by_pitch_c'] = team_games.groupby('pitcher_season')['s_hit_by_pitch'].cumsum() - team_games['s_hit_by_pitch']
team_games['s_hit_by_pitch_a'] = team_games['s_hit_by_pitch_c'] / team_games['s_pitcher_games']

team_games['s_outs_c'] = team_games.groupby('pitcher_season')['s_outs'].cumsum() - team_games['s_outs']
team_games['s_outs_a'] = team_games['s_outs_c'] / team_games['s_pitcher_games']

team_games['s_strikeout_c'] = team_games.groupby('pitcher_season')['s_strikeout'].cumsum() - team_games['s_strikeout']
team_games['s_strikeout_a'] = team_games['s_strikeout_c'] / team_games['s_pitcher_games']

team_games['s_intentional_walk_c'] = team_games.groupby('pitcher_season')['s_intentional_walk'].cumsum() - team_games['s_intentional_walk']
team_games['s_intentional_walk_a'] = team_games['s_intentional_walk_c'] / team_games['s_pitcher_games']

team_games['s_single_c'] = team_games.groupby('pitcher_season')['s_single'].cumsum() - team_games['s_single']
team_games['s_single_a'] = team_games['s_single_c'] / team_games['s_pitcher_games']

team_games['s_double_c'] = team_games.groupby('pitcher_season')['s_double'].cumsum() - team_games['s_double']
team_games['s_double_a'] = team_games['s_double_c'] / team_games['s_pitcher_games']

team_games['s_triple_c'] = team_games.groupby('pitcher_season')['s_triple'].cumsum() - team_games['s_triple']
team_games['s_triple_a'] = team_games['s_triple_c'] / team_games['s_pitcher_games']

team_games['s_hr_c'] = team_games.groupby('pitcher_season')['s_home_run'].cumsum() - team_games['s_home_run']
team_games['s_hr_a'] = team_games['s_hr_c'] / team_games['s_pitcher_games']

team_games['s_sac_fly_c'] = team_games.groupby('pitcher_season')['s_sac_fly'].cumsum() - team_games['s_sac_fly']
team_games['s_sac_fly_a'] = team_games['s_sac_fly_c'] / team_games['s_pitcher_games']

team_games['s_sac_hit_c'] = team_games.groupby('pitcher_season')['s_sac_hit'].cumsum() - team_games['s_sac_hit']
team_games['s_sac_hit_a'] = team_games['s_sac_hit_c'] / team_games['s_pitcher_games']

team_games['s_ab_c'] = team_games.groupby('pitcher_season')['s_ab'].cumsum() - team_games['s_ab']
team_games['s_ab_a'] = team_games['s_ab_c'] / team_games['s_pitcher_games']

team_games['s_hits_c'] = team_games['s_single_c'] + team_games['s_double_c'] + team_games['s_triple_c'] + team_games['s_hr_c']
team_games['s_hits_a'] = team_games['s_hits_c'] / team_games['s_pitcher_games']


# the type of contact a pitcher gives up
team_games['s_gb_c'] = team_games.groupby('s_pitcher')['s_groundball'].cumsum() - team_games['s_groundball']
team_games['s_gb_a'] = team_games['s_gb_c'] / team_games['s_pitcher_games']

team_games['s_fb_c'] = team_games.groupby('s_pitcher')['s_flyball'].cumsum() - team_games['s_flyball']
team_games['s_fb_a'] = team_games['s_fb_c'] / team_games['s_pitcher_games']

team_games['s_pop_c'] = team_games.groupby('s_pitcher')['s_popup'].cumsum() - team_games['s_popup']
team_games['s_pop_a'] = team_games['s_pop_c'] / team_games['s_pitcher_games']

team_games['s_ld_c'] = team_games.groupby('s_pitcher')['s_linedrive'].cumsum() - team_games['s_linedrive']
team_games['s_ld_a'] = team_games['s_ld_c'] / team_games['s_pitcher_games']

# how the team is seeing the pitcher's throws
team_games['s_balls_c'] = team_games.groupby('s_pitcher')['s_balls'].cumsum() - team_games['s_balls']
team_games['s_balls_a'] = team_games['s_balls_c'] / team_games['s_pitcher_games']

team_games['s_strikes_c'] = team_games.groupby('s_pitcher')['s_strikes'].cumsum() - team_games['s_strikes']
team_games['s_strikes_a'] = team_games['s_strikes_c'] / team_games['s_pitcher_games']

team_games['s_called_strikes_c'] = team_games.groupby('s_pitcher')['s_called_strikes'].cumsum() - team_games['s_called_strikes']
team_games['s_called_strikes_a'] = team_games['s_called_strikes_c'] / team_games['s_pitcher_games']

team_games['s_swinging_strikes_c'] = team_games.groupby('s_pitcher')['s_swinging_strike'].cumsum() - team_games['s_swinging_strike']
team_games['s_swinging_strikes_a'] = team_games['s_swinging_strikes_c'] / team_games['s_pitcher_games']

# pitcher's defensive/offensive support
team_games['s_errors_c'] = team_games.groupby('s_pitcher')['s_error'].cumsum() - team_games['s_error']
team_games['s_errors_a'] = team_games['s_errors_c'] / team_games['s_pitcher_games']

team_games['s_off_runs_c'] = team_games.groupby('s_pitcher')['bat_batter_scored'].cumsum() - team_games['bat_batter_scored']
team_games['s_off_runs_a'] = team_games['s_off_runs_c'] / team_games['s_pitcher_games']

                                                                                                 
# how a bullpen lets teams on base
team_games['b_walk_c'] = team_games.groupby('team_season')['b_walk'].cumsum() - team_games['b_walk']
team_games['b_walk_a'] = team_games['b_walk_c'] / team_games['games_played']

team_games['b_hit_by_pitch_c'] = team_games.groupby('team_season')['b_hit_by_pitch'].cumsum() - team_games['b_hit_by_pitch']
team_games['b_hit_by_pitch_a'] = team_games['b_hit_by_pitch_c'] / team_games['games_played']

team_games['b_outs_c'] = team_games.groupby('team_season')['b_outs'].cumsum() - team_games['b_outs']
team_games['b_outs_a'] = team_games['b_outs_c'] / team_games['games_played']

team_games['b_strikeout_c'] = team_games.groupby('team_season')['b_strikeout'].cumsum() - team_games['b_strikeout']
team_games['b_strikeout_a'] = team_games['b_strikeout_c'] / team_games['games_played']

team_games['b_intentional_walk_c'] = team_games.groupby('pitcher_season')['b_intentional_walk'].cumsum() - team_games['b_intentional_walk']
team_games['b_intentional_walk_a'] = team_games['b_intentional_walk_c'] / team_games['games_played']

team_games['b_single_c'] = team_games.groupby('team_season')['b_single'].cumsum() - team_games['b_single']
team_games['b_single_a'] = team_games['b_single_c'] / team_games['games_played']

team_games['b_double_c'] = team_games.groupby('team_season')['b_double'].cumsum() - team_games['b_double']
team_games['b_double_a'] = team_games['b_double_c'] / team_games['games_played']

team_games['b_triple_c'] = team_games.groupby('team_season')['b_triple'].cumsum() - team_games['b_triple']
team_games['b_triple_a'] = team_games['b_triple_c'] / team_games['games_played']

team_games['b_hr_c'] = team_games.groupby('team_season')['b_home_run'].cumsum() - team_games['b_home_run']
team_games['b_hr_a'] = team_games['b_hr_c'] / team_games['games_played']

team_games['b_sac_fly_c'] = team_games.groupby('team_season')['b_sac_fly'].cumsum() - team_games['b_sac_fly']
team_games['b_sac_fly_a'] = team_games['b_sac_fly_c'] / team_games['games_played']

team_games['b_sac_hit_c'] = team_games.groupby('team_season')['b_sac_hit'].cumsum() - team_games['b_sac_hit']
team_games['b_sac_hit_a'] = team_games['b_sac_hit_c'] / team_games['games_played']

team_games['b_hits_c'] = team_games['b_single_c'] + team_games['b_double_c'] + team_games['b_triple_c'] + team_games['b_hr_c']
team_games['b_hits_a'] = team_games['b_hits_c'] / team_games['games_played']


# the type of contact a bullpen gives up
team_games['b_gb_c'] = team_games.groupby('team_season')['b_groundball'].cumsum() - team_games['b_groundball']
team_games['b_gb_a'] = team_games['b_gb_c'] / team_games['games_played']

team_games['b_fb_c'] = team_games.groupby('team_season')['b_flyball'].cumsum() - team_games['b_flyball']
team_games['b_fb_a'] = team_games['b_fb_c'] / team_games['games_played']

team_games['b_pop_c'] = team_games.groupby('team_season')['b_popup'].cumsum() - team_games['b_popup']
team_games['b_pop_a'] = team_games['b_pop_c'] / team_games['games_played']

team_games['b_ld_c'] = team_games.groupby('team_season')['b_linedrive'].cumsum() - team_games['b_linedrive']
team_games['b_ld_a'] = team_games['b_ld_c'] / team_games['games_played']

# how the team is seeing the bullpen's throws
team_games['b_balls_c'] = team_games.groupby('team_season')['b_balls'].cumsum() - team_games['b_balls']
team_games['b_balls_a'] = team_games['b_balls_c'] / team_games['games_played']

team_games['b_strikes_c'] = team_games.groupby('team_season')['b_strikes'].cumsum() - team_games['b_strikes']
team_games['b_strikes_a'] = team_games['b_strikes_c'] / team_games['games_played']

team_games['b_called_strikes_c'] = team_games.groupby('team_season')['b_called_strikes'].cumsum() - team_games['b_called_strikes']
team_games['b_called_strikes_a'] = team_games['b_called_strikes_c'] / team_games['games_played']

team_games['b_swinging_strikes_c'] = team_games.groupby('team_season')['b_swinging_strike'].cumsum() - team_games['b_swinging_strike']
team_games['b_swinging_strikes_a'] = team_games['b_swinging_strikes_c'] / team_games['games_played']

team_games['b_ab_c'] = team_games.groupby('team_season')['b_ab'].cumsum() - team_games['b_ab']
team_games['b_ab_a'] = team_games['b_ab_c'] / team_games['games_played']

# bullpen's defensive/offensive support
team_games['b_errors_c'] = team_games.groupby('team_season')['b_error'].cumsum() - team_games['b_error']
team_games['b_errors_a'] = team_games['b_errors_c'] / team_games['games_played']

team_games['b_off_runs_c'] = team_games.groupby('team_season')['bat_batter_scored'].cumsum() - team_games['bat_batter_scored']
team_games['b_off_runs_a'] = team_games['b_off_runs_c'] / team_games['games_played']

# %%
# how a team got on base
team_games['bat_walk_5'] = team_games.groupby('team_season')['bat_walk'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_walk']
team_games['bat_walk_5_avg'] = team_games['bat_walk_5']/5

team_games['bat_hit_by_pitch_5'] = team_games.groupby('team_season')['bat_hit_by_pitch'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_hit_by_pitch']
team_games['bat_hit_by_pitch_5_avg'] = team_games['bat_hit_by_pitch_5']/5

team_games['bat_outs_5'] = team_games.groupby('team_season')['bat_outs'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_outs']
team_games['bat_outs_5_avg'] = team_games['bat_outs_5']/5

team_games['bat_strikeout_5'] = team_games.groupby('team_season')['bat_strikeout'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_strikeout']
team_games['bat_strikeout_5_avg'] = team_games['bat_strikeout_5']/5

team_games['bat_intentional_walk_5'] = team_games.groupby('team_season')['bat_intentional_walk'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_intentional_walk']
team_games['bat_intentional_walk_5_avg'] = team_games['bat_intentional_walk_5']/5

team_games['bat_single_5'] = team_games.groupby('team_season')['bat_single'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_single']
team_games['bat_single_5_avg'] = team_games['bat_single_5']/5

team_games['bat_double_5'] = team_games.groupby('team_season')['bat_double'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_double']
team_games['bat_double_5_avg'] = team_games['bat_double_5']/5

team_games['bat_triple_5'] = team_games.groupby('team_season')['bat_triple'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_triple']
team_games['bat_triple_5_avg'] = team_games['bat_triple_5']/5

team_games['bat_hr_5'] = team_games.groupby('team_season')['bat_home_run'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_home_run']
team_games['bat_hr_5_avg'] = team_games['bat_hr_5']/5

team_games['bat_sac_fly_5'] = team_games.groupby('team_season')['bat_sac_fly'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_sac_fly']
team_games['bat_sac_fly_5_avg'] = team_games['bat_sac_fly_5']/5

team_games['bat_sac_hit_5'] = team_games.groupby('team_season')['bat_sac_hit'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_sac_hit']
team_games['bat_sac_hit_5_avg'] = team_games['bat_sac_hit_5']/5

team_games['bat_ab_5'] = team_games.groupby('team_season')['bat_ab'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_ab']
team_games['bat_ab_5_avg'] = team_games['bat_ab_5']/5

team_games['bat_hits_5'] = team_games['bat_single_5'] + team_games['bat_double_5'] + team_games['bat_triple_5'] + team_games['bat_hr_5']
team_games['bat_hits_5_avg'] = team_games['bat_hits_5'] / 5

# the type of contact a team is making
team_games['bat_gb_5'] = team_games.groupby('team_season')['bat_groundball'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_groundball']
team_games['bat_gb_5-avg'] = team_games['bat_gb_5']/5

team_games['bat_fb_5'] = team_games.groupby('team_season')['bat_flyball'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_flyball']
team_games['bat_fb_5_avg'] = team_games['bat_fb_5']/5

team_games['bat_pop_5'] = team_games.groupby('team_season')['bat_popup'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_popup']
team_games['bat_pop_5_avg'] = team_games['bat_pop_5']/5

team_games['bat_ld_5'] = team_games.groupby('team_season')['bat_linedrive'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_linedrive']
team_games['bat_ld_5_avg'] = team_games['bat_ld_5']/5

# how the team is seeing the ball
team_games['bat_balls_5'] = team_games.groupby('team_season')['bat_balls_in_plate_app'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_balls_in_plate_app']
team_games['bat_balls_5_avg'] = team_games['bat_balls_5']/5

team_games['bat_strikes_5'] = team_games.groupby('team_season')['bat_strikes_in_plate_app'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_strikes_in_plate_app']
team_games['bat_strikes_5_avg'] = team_games['bat_strikes_5']/5

team_games['bat_called_strikes_5'] = team_games.groupby('team_season')['bat_called_strikes_plate_app'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_called_strikes_plate_app']
team_games['bat_called_strikes_5_avg'] = team_games['bat_called_strikes_5']/5

team_games['bat_swinging_strikes_5'] = team_games.groupby('team_season')['bat_swinging_strike_plate_app'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_swinging_strike_plate_app']
team_games['bat_swinging_strikes_5_avg'] = team_games['bat_swinging_strikes_5']/5

# data calculated after fifth start of season
# how a starting pitcher lets teams on base
team_games['s_walk_5'] = team_games.groupby('s_pitcher')['s_walk'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_walk']
team_games['s_walk_5_avg'] = team_games['s_walk_5']/5

team_games['s_hit_by_pitch_5'] = team_games.groupby('s_pitcher')['s_hit_by_pitch'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_hit_by_pitch']
team_games['s_hit_by_pitch_5_avg'] = team_games['s_hit_by_pitch_5']/5

team_games['s_outs_5'] = team_games.groupby('s_pitcher')['s_outs'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_outs']
team_games['s_outs_5_avg'] = team_games['s_outs_5']/5

team_games['s_strikeout_5'] = team_games.groupby('s_pitcher')['s_strikeout'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_strikeout']
team_games['s_strikeout_5_avg'] = team_games['s_strikeout_5']/5

team_games['s_intentional_walk_5'] = team_games.groupby('s_pitcher')['s_intentional_walk'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_intentional_walk']
team_games['s_intentional_walk_5_avg'] = team_games['s_intentional_walk_5']/5

team_games['s_single_5'] = team_games.groupby('s_pitcher')['s_single'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_single']
team_games['s_single_5_avg'] = team_games['s_single_5']/5

team_games['s_double_5'] = team_games.groupby('s_pitcher')['s_double'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_double']
team_games['s_double_5_avg'] = team_games['s_double_5']/5

team_games['s_triple_5'] = team_games.groupby('s_pitcher')['s_triple'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_triple']
team_games['s_double_5_avg'] = team_games['s_double_5']/5

team_games['s_hr_5'] = team_games.groupby('s_pitcher')['s_home_run'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_home_run']
team_games['s_hr_5_avg'] = team_games['s_hr_5']/5

team_games['s_sac_fly_5'] = team_games.groupby('team_season')['s_sac_fly'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_sac_fly']
team_games['s_sac_fly_5_avg'] = team_games['s_sac_fly_5']/5

team_games['s_sac_hit_5'] = team_games.groupby('team_season')['s_sac_hit'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_sac_hit']
team_games['s_sac_hit_5_avg'] = team_games['s_sac_hit_5']/5

team_games['s_ab_5'] = team_games.groupby('team_season')['s_ab'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_ab']
team_games['s_ab_5_avg'] = team_games['s_ab_5']/5

team_games['s_hits_5'] = team_games['s_single_5'] + team_games['s_double_5'] + team_games['s_triple_5'] + team_games['s_hr_5']
team_games['s_hits_5_avg'] = team_games['s_hits_5'] / 5

# the type of contact a pitcher gives up
team_games['s_gb_5'] = team_games.groupby('s_pitcher')['s_groundball'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_groundball']
team_games['s_gb_5_avg'] = team_games['s_gb_5']/5

team_games['s_fb_5'] = team_games.groupby('s_pitcher')['s_flyball'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_flyball']
team_games['s_fb_5_avg'] = team_games['s_fb_5']/5

team_games['s_pop_5'] = team_games.groupby('s_pitcher')['s_popup'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_popup']
team_games['s_pop_5_avg'] = team_games['s_pop_5']/5

team_games['s_ld_5'] = team_games.groupby('s_pitcher')['s_linedrive'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_linedrive']
team_games['s_ld_5_avg'] = team_games['s_ld_5']/5


# how the team is seeing the pitcher's throws
team_games['s_balls_5'] = team_games.groupby('s_pitcher')['s_balls'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_balls']
team_games['s_balls_5_avg'] = team_games['s_balls_5']/5

team_games['s_strikes_5'] = team_games.groupby('s_pitcher')['s_strikes'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_strikes']
team_games['s_strikes_5_avg'] = team_games['s_strikes_5']/5

team_games['s_called_strikes_5'] = team_games.groupby('s_pitcher')['s_called_strikes'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_called_strikes']
team_games['s_called_strikes_5_avg'] = team_games['s_called_strikes_5']/5

team_games['s_swinging_strikes_5'] = team_games.groupby('s_pitcher')['s_swinging_strike'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_swinging_strike']
team_games['s_swinging_strikes_5_avg'] = team_games['s_swinging_strikes_5']/5


# pitcher's defensive/offensive support
team_games['s_errors_5'] = team_games.groupby('s_pitcher')['s_error'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_error']
team_games['s_swinging_strikes_5_avg'] = team_games['s_swinging_strikes_5']/5

team_games['s_off_runs_5'] = team_games.groupby('s_pitcher')['bat_batter_scored'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_batter_scored']
team_games['s_off_runs_5_avg'] = team_games['s_off_runs_5']/5


# how a bullpen lets teams on base
team_games['b_walk_5'] = team_games.groupby('team_season')['b_walk'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_walk']
team_games['b_walk_5_avg'] = team_games['b_walk_5']/5

team_games['b_hit_by_pitch_5'] = team_games.groupby('team_season')['b_hit_by_pitch'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_hit_by_pitch']
team_games['b_hit_by_pitch_5_avg'] = team_games['b_hit_by_pitch_5']/5

team_games['b_outs_5'] = team_games.groupby('team_season')['b_outs'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_outs']
team_games['b_outs_5_avg'] = team_games['b_outs_5']/5

team_games['b_strikeout_5'] = team_games.groupby('team_season')['b_strikeout'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_strikeout']
team_games['b_strikeout_5_avg'] = team_games['b_strikeout_5']/5

team_games['b_intentional_walk_5'] = team_games.groupby('team_season')['b_intentional_walk'].rolling(6).sum().reset_index(0,drop=True) - team_games['s_intentional_walk']
team_games['b_walk_5_avg'] = team_games['b_intentional_walk_5']/5

team_games['b_single_5'] = team_games.groupby('team_season')['b_single'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_single']
team_games['b_single_5_avg'] = team_games['b_single_5']/5

team_games['b_double_5'] = team_games.groupby('team_season')['b_double'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_double']
team_games['b_double_5_avg'] = team_games['b_double_5']/5

team_games['b_triple_5'] = team_games.groupby('team_season')['b_triple'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_triple']
team_games['b_triple_5_avg'] = team_games['b_triple_5']/5

team_games['b_hr_5'] = team_games.groupby('team_season')['b_home_run'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_home_run']
team_games['b_hr_5_avg'] = team_games['b_hr_5']/5

team_games['b_sac_fly_5'] = team_games.groupby('team_season')['b_sac_fly'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_sac_fly']
team_games['b_sac_fly_5_avg'] = team_games['b_sac_fly_5']/5

team_games['b_sac_hit_5'] = team_games.groupby('team_season')['b_sac_hit'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_sac_hit']
team_games['b_sac_hit_5_avg'] = team_games['b_sac_hit_5']/5

team_games['b_ab_5'] = team_games.groupby('team_season')['b_ab'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_ab']
team_games['b_ab_5_avg'] = team_games['b_ab_5']/5

team_games['b_hits_5'] = team_games['b_single_5'] + team_games['b_double_5'] + team_games['b_triple_5'] + team_games['b_hr_5']
team_games['b_hits_5_avg'] = team_games['b_hits_5'] / 5

# the type of contact a bullpen gives up
team_games['b_gb_5'] = team_games.groupby('team_season')['b_groundball'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_groundball']
team_games['b_gb_5_avg'] = team_games['b_gb_5']/5

team_games['b_fb_5'] = team_games.groupby('team_season')['b_flyball'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_flyball']
team_games['b_fb_5_avg'] = team_games['b_fb_5']/5

team_games['b_pop_5'] = team_games.groupby('team_season')['b_popup'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_popup']
team_games['b_pop_5_avg'] = team_games['b_pop_5']/5

team_games['b_ld_5'] = team_games.groupby('team_season')['b_linedrive'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_linedrive']
team_games['b_ld_5_avg'] = team_games['b_ld_5']/5


# how the team is seeing the bullpen's throws
team_games['b_balls_5'] = team_games.groupby('team_season')['b_balls'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_balls']
team_games['b_balls_5_avg'] = team_games['b_balls_5']/5

team_games['b_strikes_5'] = team_games.groupby('team_season')['b_strikes'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_strikes']
team_games['b_strikes_5_avg'] = team_games['b_strikes_5']/5

team_games['b_called_strikes_5'] = team_games.groupby('team_season')['b_called_strikes'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_called_strikes']
team_games['b_called_strikes_5_avg'] = team_games['b_called_strikes_5']/5

team_games['b_swinging_strikes_5'] = team_games.groupby('team_season')['b_swinging_strike'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_swinging_strike']
team_games['b_swinging_strikes_5_avg'] = team_games['b_swinging_strikes_5']/5


# bullpen's defensive/offensive support
team_games['b_errors_5'] = team_games.groupby('team_season')['b_error'].rolling(6).sum().reset_index(0,drop=True) - team_games['b_error']
team_games['b_errors_5_avg'] = team_games['b_errors_5']/5

team_games['b_off_runs_5'] = team_games.groupby('team_season')['bat_batter_scored'].rolling(6).sum().reset_index(0,drop=True) - team_games['bat_batter_scored']
team_games['b_off_runs_5_avg'] = team_games['b_off_runs_5']/5

# %%
# how a team got on base
team_games['bat_walk_10'] = team_games.groupby('team_season')['bat_walk'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_walk']
team_games['bat_walk_10_avg'] = team_games['bat_walk_10']/10

team_games['bat_hit_by_pitch_10'] = team_games.groupby('team_season')['bat_hit_by_pitch'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_hit_by_pitch']
team_games['bat_hit_by_pitch_10_avg'] = team_games['bat_hit_by_pitch_10']/10

team_games['bat_intentional_walk_10'] = team_games.groupby('team_season')['bat_intentional_walk'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_intentional_walk']
team_games['bat_intentional_walk_10_avg'] = team_games['bat_intentional_walk_10']/10

team_games['bat_outs_10'] = team_games.groupby('team_season')['bat_outs'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_outs']
team_games['bat_outs_10_avg'] = team_games['bat_outs_10']/10

team_games['bat_strikeout_10'] = team_games.groupby('team_season')['bat_strikeout'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_strikeout']
team_games['bat_strikeout_10_avg'] = team_games['bat_strikeout_10']/10

team_games['bat_intentional_walk_10'] = team_games.groupby('team_season')['bat_intentional_walk'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_intentional_walk']
team_games['bat_intentional_walk_10_avg'] = team_games['bat_intentional_walk_10']/10

team_games['bat_single_10'] = team_games.groupby('team_season')['bat_single'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_single']
team_games['bat_single_10_avg'] = team_games['bat_single_10']/10

team_games['bat_double_10'] = team_games.groupby('team_season')['bat_double'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_double']
team_games['bat_double_10_avg'] = team_games['bat_double_10']/10

team_games['bat_triple_10'] = team_games.groupby('team_season')['bat_triple'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_triple']
team_games['bat_triple_10_avg'] = team_games['bat_triple_10']/10

team_games['bat_hr_10'] = team_games.groupby('team_season')['bat_home_run'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_home_run']
team_games['bat_hr_10_avg'] = team_games['bat_hr_10']/10

team_games['bat_sac_fly_10'] = team_games.groupby('team_season')['bat_sac_fly'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_sac_fly']
team_games['bat_sac_fly_10_avg'] = team_games['bat_sac_fly_10']/10

team_games['bat_sac_hit_10'] = team_games.groupby('team_season')['bat_sac_hit'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_sac_hit']
team_games['bat_sac_hit_10_avg'] = team_games['bat_sac_hit_10']/10

team_games['bat_ab_10'] = team_games.groupby('team_season')['bat_ab'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_ab']
team_games['bat_ab_10_avg'] = team_games['bat_ab_10']/10

team_games['bat_hits_10'] = team_games['bat_single_10'] + team_games['bat_double_10'] + team_games['bat_triple_10'] + team_games['bat_hr_10']
team_games['bat_hits_10_avg'] = team_games['bat_hits_10'] / 10

# the type of contact a team is making
team_games['bat_gb_10'] = team_games.groupby('team_season')['bat_groundball'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_groundball']
team_games['bat_gb_10-avg'] = team_games['bat_gb_10']/10

team_games['bat_fb_10'] = team_games.groupby('team_season')['bat_flyball'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_flyball']
team_games['bat_fb_10_avg'] = team_games['bat_fb_10']/10

team_games['bat_pop_10'] = team_games.groupby('team_season')['bat_popup'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_popup']
team_games['bat_pop_10_avg'] = team_games['bat_pop_10']/10

team_games['bat_ld_10'] = team_games.groupby('team_season')['bat_linedrive'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_linedrive']
team_games['bat_ld_10_avg'] = team_games['bat_ld_10']/10

# how the team is seeing the ball
team_games['bat_balls_10'] = team_games.groupby('team_season')['bat_balls_in_plate_app'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_balls_in_plate_app']
team_games['bat_balls_10_avg'] = team_games['bat_balls_10']/10

team_games['bat_strikes_10'] = team_games.groupby('team_season')['bat_strikes_in_plate_app'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_strikes_in_plate_app']
team_games['bat_strikes_10_avg'] = team_games['bat_strikes_10']/10

team_games['bat_called_strikes_10'] = team_games.groupby('team_season')['bat_called_strikes_plate_app'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_called_strikes_plate_app']
team_games['bat_called_strikes_10_avg'] = team_games['bat_called_strikes_10']/10

team_games['bat_swinging_strikes_10'] = team_games.groupby('team_season')['bat_swinging_strike_plate_app'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_swinging_strike_plate_app']
team_games['bat_swinging_strikes_10_avg'] = team_games['bat_swinging_strikes_10']/10

# data calculated after fifth start of season
# how a starting pitcher lets teams on base
team_games['s_walk_10'] = team_games.groupby('s_pitcher')['s_walk'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_walk']
team_games['s_walk_10_avg'] = team_games['s_walk_10']/10

team_games['s_hit_by_pitch_10'] = team_games.groupby('s_pitcher')['s_hit_by_pitch'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_hit_by_pitch']
team_games['s_hit_by_pitch_10_avg'] = team_games['s_hit_by_pitch_10']/10

team_games['s_outs_10'] = team_games.groupby('s_pitcher')['s_outs'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_outs']
team_games['s_outs_10_avg'] = team_games['s_outs_10']/10

team_games['s_strikeout_10'] = team_games.groupby('s_pitcher')['s_strikeout'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_strikeout']
team_games['s_strikeout_10_avg'] = team_games['s_strikeout_10']/10

team_games['s_intentional_walk_10'] = team_games.groupby('s_pitcher')['s_intentional_walk'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_intentional_walk']
team_games['s_intentional_walk_10_avg'] = team_games['s_intentional_walk_10']/10

team_games['s_single_10'] = team_games.groupby('s_pitcher')['s_single'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_single']
team_games['s_single_10_avg'] = team_games['s_single_10']/10

team_games['s_double_10'] = team_games.groupby('s_pitcher')['s_double'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_double']
team_games['s_double_10_avg'] = team_games['s_double_10']/10

team_games['s_triple_10'] = team_games.groupby('s_pitcher')['s_triple'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_triple']
team_games['s_double_10_avg'] = team_games['s_double_10']/10

team_games['s_hr_10'] = team_games.groupby('s_pitcher')['s_home_run'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_home_run']
team_games['s_hr_10_avg'] = team_games['s_hr_10']/10

team_games['s_sac_fly_10'] = team_games.groupby('team_season')['s_sac_fly'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_sac_fly']
team_games['s_sac_fly_10_avg'] = team_games['s_sac_fly_10']/10

team_games['s_sac_hit_10'] = team_games.groupby('team_season')['s_sac_hit'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_sac_hit']
team_games['s_sac_hit_10_avg'] = team_games['s_sac_hit_10']/10

team_games['s_ab_10'] = team_games.groupby('team_season')['s_ab'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_ab']
team_games['s_ab_10_avg'] = team_games['s_ab_10']/10

team_games['s_hits_10'] = team_games['s_single_10'] + team_games['s_double_10'] + team_games['s_triple_10'] + team_games['s_hr_10']
team_games['s_hits_10_avg'] = team_games['s_hits_10'] / 10


# the type of contact a pitcher gives up
team_games['s_gb_10'] = team_games.groupby('s_pitcher')['s_groundball'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_groundball']
team_games['s_gb_10_avg'] = team_games['s_gb_10']/10

team_games['s_fb_10'] = team_games.groupby('s_pitcher')['s_flyball'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_flyball']
team_games['s_fb_10_avg'] = team_games['s_fb_10']/10

team_games['s_pop_10'] = team_games.groupby('s_pitcher')['s_popup'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_popup']
team_games['s_pop_10_avg'] = team_games['s_pop_10']/10

team_games['s_ld_10'] = team_games.groupby('s_pitcher')['s_linedrive'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_linedrive']
team_games['s_ld_10_avg'] = team_games['s_ld_10']/10


# how the team is seeing the pitcher's throws
team_games['s_balls_10'] = team_games.groupby('s_pitcher')['s_balls'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_balls']
team_games['s_balls_10_avg'] = team_games['s_balls_10']/10

team_games['s_strikes_10'] = team_games.groupby('s_pitcher')['s_strikes'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_strikes']
team_games['s_strikes_10_avg'] = team_games['s_strikes_10']/10

team_games['s_called_strikes_10'] = team_games.groupby('s_pitcher')['s_called_strikes'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_called_strikes']
team_games['s_called_strikes_10_avg'] = team_games['s_called_strikes_10']/10

team_games['s_swinging_strikes_10'] = team_games.groupby('s_pitcher')['s_swinging_strike'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_swinging_strike']
team_games['s_swinging_strikes_10_avg'] = team_games['s_swinging_strikes_10']/10


# pitcher's defensive/offensive support
team_games['s_errors_10'] = team_games.groupby('s_pitcher')['s_error'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_error']
team_games['s_swinging_strikes_10_avg'] = team_games['s_swinging_strikes_10']/10

team_games['s_off_runs_10'] = team_games.groupby('s_pitcher')['bat_batter_scored'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_batter_scored']
team_games['s_off_runs_10_avg'] = team_games['s_off_runs_10']/10


# how a bullpen lets teams on base
team_games['b_walk_10'] = team_games.groupby('team_season')['b_walk'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_walk']
team_games['b_walk_10_avg'] = team_games['b_walk_10']/10

team_games['b_hit_by_pitch_10'] = team_games.groupby('team_season')['b_hit_by_pitch'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_hit_by_pitch']
team_games['b_hit_by_pitch_10_avg'] = team_games['b_hit_by_pitch_10']/10

team_games['b_outs_10'] = team_games.groupby('team_season')['b_outs'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_outs']
team_games['b_outs_10_avg'] = team_games['b_outs_10']/10

team_games['b_strikeout_10'] = team_games.groupby('team_season')['b_strikeout'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_strikeout']
team_games['b_strikeout_10_avg'] = team_games['b_strikeout_10']/10

team_games['b_intentional_walk_10'] = team_games.groupby('team_season')['b_intentional_walk'].rolling(11).sum().reset_index(0,drop=True) - team_games['s_intentional_walk']
team_games['b_intentional_walk_10_avg'] = team_games['b_intentional_walk_10']/10

team_games['b_single_10'] = team_games.groupby('team_season')['b_single'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_single']
team_games['b_single_10_avg'] = team_games['b_single_10']/10

team_games['b_double_10'] = team_games.groupby('team_season')['b_double'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_double']
team_games['b_double_10_avg'] = team_games['b_double_10']/10

team_games['b_triple_10'] = team_games.groupby('team_season')['b_triple'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_triple']
team_games['b_triple_10_avg'] = team_games['b_triple_10']/10

team_games['b_hr_10'] = team_games.groupby('team_season')['b_home_run'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_home_run']
team_games['b_hr_10_avg'] = team_games['b_hr_10']/10

team_games['b_sac_fly_10'] = team_games.groupby('team_season')['b_sac_fly'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_sac_fly']
team_games['b_sac_fly_10_avg'] = team_games['b_sac_fly_10']/10

team_games['b_sac_hit_10'] = team_games.groupby('team_season')['b_sac_hit'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_sac_hit']
team_games['b_sac_hit_10_avg'] = team_games['b_sac_hit_10']/10

team_games['b_ab_10'] = team_games.groupby('team_season')['b_ab'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_ab']
team_games['b_ab_10_avg'] = team_games['b_ab_10']/10

team_games['b_hits_10'] = team_games['b_single_10'] + team_games['b_double_10'] + team_games['b_triple_10'] + team_games['b_hr_10']
team_games['b_hits_10_avg'] = team_games['b_hits_10'] / 10

# the type of contact a bullpen gives up
team_games['b_gb_10'] = team_games.groupby('team_season')['b_groundball'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_groundball']
team_games['b_gb_10_avg'] = team_games['b_gb_10']/10

team_games['b_fb_10'] = team_games.groupby('team_season')['b_flyball'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_flyball']
team_games['b_fb_10_avg'] = team_games['b_fb_10']/10

team_games['b_pop_10'] = team_games.groupby('team_season')['b_popup'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_popup']
team_games['b_pop_10_avg'] = team_games['b_pop_10']/10

team_games['b_ld_10'] = team_games.groupby('team_season')['b_linedrive'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_linedrive']
team_games['b_ld_10_avg'] = team_games['b_ld_10']/10

# how the team is seeing the bullpen's throws
team_games['b_balls_10'] = team_games.groupby('team_season')['b_balls'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_balls']
team_games['b_balls_10_avg'] = team_games['b_balls_10']/10

team_games['b_strikes_10'] = team_games.groupby('team_season')['b_strikes'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_strikes']
team_games['b_strikes_10_avg'] = team_games['b_strikes_10']/10

team_games['b_called_strikes_10'] = team_games.groupby('team_season')['b_called_strikes'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_called_strikes']
team_games['b_called_strikes_10_avg'] = team_games['b_called_strikes_10']/10

team_games['b_swinging_strikes_10'] = team_games.groupby('team_season')['b_swinging_strike'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_swinging_strike']
team_games['b_swinging_strikes_10_avg'] = team_games['b_swinging_strikes_10']/10

# bullpen's defensive/offensive support
team_games['b_errors_10'] = team_games.groupby('team_season')['b_error'].rolling(11).sum().reset_index(0,drop=True) - team_games['b_error']
team_games['b_errors_10_avg'] = team_games['b_errors_10']/10

team_games['b_off_runs_10'] = team_games.groupby('team_season')['bat_batter_scored'].rolling(11).sum().reset_index(0,drop=True) - team_games['bat_batter_scored']
team_games['b_off_runs_10_avg'] = team_games['b_off_runs_10']/10

# %%
team_games['b_bip_c'] = team_games['b_gb_c'] + team_games['b_fb_c'] + team_games['b_pop_c'] + team_games['b_ld_c']
team_games['b_gbr_c'] = team_games['b_gb_c'] / team_games['b_bip_c']
team_games['b_fbr_c'] = team_games['b_fb_c'] / team_games['b_bip_c']
team_games['b_popr_c'] = team_games['b_pop_c'] / team_games['b_bip_c']
team_games['b_ldr_c'] = team_games['b_ld_c'] / team_games['b_bip_c']
team_games['b_hr_fb_c'] = team_games['b_hr_5'] / team_games['b_fb_5']

team_games['s_bip_c'] = team_games['s_gb_c'] + team_games['s_fb_c'] + team_games['s_pop_c'] + team_games['s_ld_c']
team_games['s_gbr_c'] = team_games['s_gb_c'] / team_games['s_bip_c']
team_games['s_fbr_c'] = team_games['s_fb_c'] / team_games['s_bip_c']
team_games['s_popr_c'] = team_games['s_pop_c'] / team_games['s_bip_c']
team_games['s_ldr_c'] = team_games['s_ld_c'] / team_games['s_bip_c']
team_games['s_hr_fb_c'] = team_games['s_hr_c'] / team_games['s_fb_c']

team_games['bat_bip_c'] = team_games['bat_gb_c'] + team_games['bat_fb_c'] + team_games['bat_pop_c'] + team_games['bat_ld_c']
team_games['bat_gbr_c'] = team_games['bat_gb_c'] / team_games['bat_bip_c']
team_games['bat_fbr_c'] = team_games['bat_fb_c'] / team_games['bat_bip_c']
team_games['bat_popr_c'] = team_games['bat_pop_c'] / team_games['bat_bip_c']
team_games['bat_ldr_c'] = team_games['bat_ld_c'] / team_games['bat_bip_c']
team_games['bat_hr_fb_c'] = team_games['bat_hr_c'] / team_games['bat_fb_c']

team_games['b_bip_5'] = team_games['b_gb_5'] + team_games['b_fb_5'] + team_games['b_pop_5'] + team_games['b_ld_5']
team_games['b_gbr_5'] = team_games['b_gb_5'] / team_games['b_bip_5']
team_games['b_fbr_5'] = team_games['b_fb_5'] / team_games['b_bip_5']
team_games['b_popr_5'] = team_games['b_pop_5'] / team_games['b_bip_5']
team_games['b_ldr_5'] = team_games['b_ld_5'] / team_games['b_bip_5']
team_games['b_hr_fb_5'] = team_games['b_hr_5'] / team_games['b_fb_5']

team_games['s_bip_5'] = team_games['s_gb_5'] + team_games['s_fb_5'] + team_games['s_pop_5'] + team_games['s_ld_5']
team_games['s_gbr_5'] = team_games['s_gb_5'] / team_games['s_bip_5']
team_games['s_fbr_5'] = team_games['s_fb_5'] / team_games['s_bip_5']
team_games['s_popr_5'] = team_games['s_pop_5'] / team_games['s_bip_5']
team_games['s_ldr_5'] = team_games['s_ld_5'] / team_games['s_bip_5']
team_games['s_hr_fb_5'] = team_games['s_hr_5'] / team_games['s_fb_5']

team_games['bat_bip_5'] = team_games['bat_gb_5'] + team_games['bat_fb_5'] + team_games['bat_pop_5'] + team_games['bat_ld_5']
team_games['bat_gbr_5'] = team_games['bat_gb_5'] / team_games['bat_bip_5']
team_games['bat_fbr_5'] = team_games['bat_fb_5'] / team_games['bat_bip_5']
team_games['bat_popr_5'] = team_games['bat_pop_5'] / team_games['bat_bip_5']
team_games['bat_ldr_5'] = team_games['bat_ld_5'] / team_games['bat_bip_5']
team_games['bat_hr_fb_5'] = team_games['bat_hr_5'] / team_games['bat_fb_5']

team_games['b_bip_10'] = team_games['b_gb_10'] + team_games['b_fb_10'] + team_games['b_pop_10'] + team_games['b_ld_10']
team_games['b_gbr_10'] = team_games['b_gb_10'] / team_games['b_bip_10']
team_games['b_fbr_10'] = team_games['b_fb_10'] / team_games['b_bip_10']
team_games['b_popr_10'] = team_games['b_pop_10'] / team_games['b_bip_10']
team_games['b_ldr_10'] = team_games['b_ld_10'] / team_games['b_bip_10']
team_games['b_hr_fb_10'] = team_games['b_hr_10'] / team_games['b_fb_10']

team_games['s_bip_10'] = team_games['s_gb_10'] + team_games['s_fb_10'] + team_games['s_pop_10'] + team_games['s_ld_10']
team_games['s_gbr_10'] = team_games['s_gb_10'] / team_games['s_bip_10']
team_games['s_fbr_10'] = team_games['s_fb_10'] / team_games['s_bip_10']
team_games['s_popr_10'] = team_games['s_pop_10'] / team_games['s_bip_10']
team_games['s_ldr_10'] = team_games['s_ld_10'] / team_games['s_bip_10']
team_games['s_hr_fb_10'] = team_games['s_hr_10'] / team_games['s_fb_10']

team_games['bat_bip_10'] = team_games['bat_gb_10'] + team_games['bat_fb_10'] + team_games['bat_pop_10'] + team_games['bat_ld_10']
team_games['bat_gbr_10'] = team_games['bat_gb_10'] / team_games['bat_bip_10']
team_games['bat_fbr_10'] = team_games['bat_fb_10'] / team_games['bat_bip_10']
team_games['bat_popr_10'] = team_games['bat_pop_10'] / team_games['bat_bip_10']
team_games['bat_ldr_10'] = team_games['bat_ld_10'] / team_games['bat_bip_10']
team_games['bat_hr_fb_10'] = team_games['bat_hr_10'] / team_games['bat_fb_10']

team_games['lg_hr_fb'] = 0.10

# %%
def zero_outs(outs_column):
    c = []
    for row in outs_column:
        if row == 0:
            o = 1
        else:
            o = row
        c.append(o)
    return c

# %%
team_games['bat_outs_c'] = zero_outs(team_games['bat_outs_c'])
team_games['bat_outs_5'] = zero_outs(team_games['bat_outs_5'])
team_games['bat_outs_10'] = zero_outs(team_games['bat_outs_10'])

team_games['s_outs_c'] = zero_outs(team_games['s_outs_c'])
team_games['s_outs_5'] = zero_outs(team_games['s_outs_5'])
team_games['s_outs_10'] = zero_outs(team_games['s_outs_10'])

team_games['b_outs_c'] = zero_outs(team_games['b_outs_c'])
team_games['b_outs_5'] = zero_outs(team_games['b_outs_5'])
team_games['b_outs_10'] = zero_outs(team_games['b_outs_10'])

# %%
team_games['bat_kb_r_c'] = team_games['bat_strikeout_c'] / team_games['bat_walk_c']
team_games['bat_kb_r_5'] = team_games['bat_strikeout_5'] / team_games['bat_walk_5']
team_games['bat_kb_r_10'] = team_games['bat_strikeout_10'] / team_games['bat_walk_10']

team_games['b_kb_r_c'] = team_games['b_strikeout_c'] / team_games['b_walk_c']
team_games['b_kb_r_5'] = team_games['b_strikeout_5'] / team_games['b_walk_5']
team_games['b_kb_r_10'] = team_games['b_strikeout_10'] / team_games['b_walk_10']

team_games['s_kb_r_c'] = team_games['s_strikeout_c'] / team_games['s_walk_c']
team_games['s_kb_r_5'] = team_games['s_strikeout_5'] / team_games['s_walk_5']
team_games['s_kb_r_10'] = team_games['s_strikeout_10'] / team_games['s_walk_10']

# %%
# need total League_HR-FB% to finish calculation
team_games['bat_xFIP_c'] = (13*(team_games['bat_hr_c']) + 3*(team_games['bat_walk_c'] + team_games['bat_intentional_walk_c']) - 2*team_games['bat_strikeout_c'])/(team_games['bat_outs_c']/3)
team_games['bat_wOBA_c'] = (.69*team_games['bat_walk_c'] + .72*team_games['bat_intentional_walk_c'] + .89*team_games['bat_single_c'] + 1.27*team_games['bat_double_c'] + 1.62*team_games['bat_triple_c'] + 2.1*team_games['bat_hr_c'])/(team_games['bat_ab_c'] + team_games['bat_walk_c'] - team_games['bat_intentional_walk_c'] + team_games['bat_sac_fly_c'] + team_games['bat_hit_by_pitch_c'])
team_games['bat_BABIP_c'] = (team_games['bat_hits_c'] - team_games['bat_hr_c'])/(team_games['bat_ab_c'] - team_games['bat_strikeout_c'] - team_games['bat_hr_c'] + team_games['bat_sac_fly_c'])

team_games['bat_xFIP_5'] = (13*(team_games['bat_hr_5']) + 3*(team_games['bat_walk_5'] + team_games['bat_intentional_walk_5']) - 2*team_games['bat_strikeout_5'])/(team_games['bat_outs_5']/3)
team_games['bat_wOBA_5'] = (.69*team_games['bat_walk_5'] + .72*team_games['bat_intentional_walk_5'] + .89*team_games['bat_single_5'] + 1.27*team_games['bat_double_5'] + 1.62*team_games['bat_triple_5'] + 2.1*team_games['bat_hr_5'])/(team_games['bat_ab_5'] + team_games['bat_walk_5'] - team_games['bat_intentional_walk_5'] + team_games['bat_sac_fly_5'] + team_games['bat_hit_by_pitch_5'])
team_games['bat_BABIP_5'] = (team_games['bat_hits_5'] - team_games['bat_hr_5'])/(team_games['bat_ab_5'] - team_games['bat_strikeout_5'] - team_games['bat_hr_5'] + team_games['bat_sac_fly_5'])

team_games['bat_xFIP_10'] = (13*(team_games['bat_hr_10']) + 3*(team_games['bat_walk_10'] + team_games['bat_intentional_walk_10']) - 2*team_games['bat_strikeout_10'])/(team_games['bat_outs_10']/3)
team_games['bat_wOBA_10'] = (.69*team_games['bat_walk_10'] + .72*team_games['bat_intentional_walk_10'] + .89*team_games['bat_single_10'] + 1.27*team_games['bat_double_10'] + 1.62*team_games['bat_triple_10'] + 2.1*team_games['bat_hr_10'])/(team_games['bat_ab_10'] + team_games['bat_walk_10'] - team_games['bat_intentional_walk_10'] + team_games['bat_sac_fly_10'] + team_games['bat_hit_by_pitch_10'])
team_games['bat_BABIP_10'] = (team_games['bat_hits_10'] - team_games['bat_hr_10'])/(team_games['bat_ab_10'] - team_games['bat_strikeout_10'] - team_games['bat_hr_10'] + team_games['bat_sac_fly_10'])


team_games['s_xFIP_c'] = (13*(team_games['s_hr_c']) + 3*(team_games['s_walk_c'] + team_games['s_intentional_walk_c']) - 2*team_games['s_strikeout_c'])/(team_games['s_outs_c']/3)
team_games['s_wOBA_c'] = (.69*team_games['s_walk_c'] + .72*team_games['s_intentional_walk_c'] + .89*team_games['s_single_c'] + 1.27*team_games['s_double_c'] + 1.62*team_games['s_triple_c'] + 2.1*team_games['s_hr_c'])/(team_games['s_ab_c'] + team_games['s_walk_c'] - team_games['s_intentional_walk_c'] + team_games['s_sac_fly_c'] + team_games['s_hit_by_pitch_c'])
team_games['s_BABIP_c'] = (team_games['s_hits_c'] - team_games['s_hr_c'])/(team_games['s_ab_c'] - team_games['s_strikeout_c'] - team_games['s_hr_c'] + team_games['s_sac_fly_c'])

team_games['s_xFIP_5'] = (13*(team_games['s_hr_5']) + 3*(team_games['s_walk_5'] + team_games['s_intentional_walk_5']) - 2*team_games['s_strikeout_5'])/(team_games['s_outs_5']/3)
team_games['s_wOBA_5'] = (.69*team_games['s_walk_5'] + .72*team_games['s_intentional_walk_5'] + .89*team_games['s_single_5'] + 1.27*team_games['s_double_5'] + 1.62*team_games['s_triple_5'] + 2.1*team_games['s_hr_5'])/(team_games['s_ab_5'] + team_games['s_walk_5'] - team_games['s_intentional_walk_5'] + team_games['s_sac_fly_5'] + team_games['s_hit_by_pitch_5'])
team_games['s_BABIP_5'] = (team_games['s_hits_5'] - team_games['s_hr_5'])/(team_games['s_ab_5'] - team_games['s_strikeout_5'] - team_games['s_hr_5'] + team_games['s_sac_fly_5'])

team_games['s_xFIP_10'] = (13*(team_games['s_hr_10']) + 3*(team_games['s_walk_10'] + team_games['s_intentional_walk_10']) - 2*team_games['s_strikeout_10'])/(team_games['s_outs_10']/3)
team_games['s_wOBA_10'] = (.69*team_games['s_walk_10'] + .72*team_games['s_intentional_walk_10'] + .89*team_games['s_single_10'] + 1.27*team_games['s_double_10'] + 1.62*team_games['s_triple_10'] + 2.1*team_games['s_hr_10'])/(team_games['s_ab_10'] + team_games['s_walk_10'] - team_games['s_intentional_walk_10'] + team_games['s_sac_fly_10'] + team_games['s_hit_by_pitch_10'])
team_games['s_BABIP_10'] = (team_games['s_hits_10'] - team_games['s_hr_10'])/(team_games['s_ab_10'] - team_games['s_strikeout_10'] - team_games['s_hr_10'] + team_games['s_sac_fly_10'])


team_games['b_xFIP_c'] = (13*(team_games['b_hr_c']) + 3*(team_games['b_walk_c'] + team_games['b_intentional_walk_c']) - 2*team_games['b_strikeout_c'])/(team_games['b_outs_c']/3)
team_games['b_wOBA_c'] = (.69*team_games['b_walk_c'] + .72*team_games['b_intentional_walk_c'] + .89*team_games['b_single_c'] + 1.27*team_games['b_double_c'] + 1.62*team_games['b_triple_c'] + 2.1*team_games['b_hr_c'])/(team_games['b_ab_c'] + team_games['b_walk_c'] - team_games['b_intentional_walk_c'] + team_games['b_sac_fly_c'] + team_games['b_hit_by_pitch_c'])
team_games['b_BABIP_c'] = (team_games['b_hits_c'] - team_games['b_hr_c'])/(team_games['b_ab_c'] - team_games['b_strikeout_c'] - team_games['b_hr_c'] + team_games['b_sac_fly_c'])

team_games['b_xFIP_5'] = (13*(team_games['b_hr_5']) + 3*(team_games['b_walk_5'] + team_games['b_intentional_walk_5']) - 2*team_games['b_strikeout_5'])/(team_games['b_outs_5']/3)
team_games['b_wOBA_5'] = (.69*team_games['b_walk_5'] + .72*team_games['b_intentional_walk_5'] + .89*team_games['b_single_5'] + 1.27*team_games['b_double_5'] + 1.62*team_games['b_triple_5'] + 2.1*team_games['b_hr_5'])/(team_games['b_ab_5'] + team_games['b_walk_5'] - team_games['b_intentional_walk_5'] + team_games['b_sac_fly_5'] + team_games['b_hit_by_pitch_5'])
team_games['b_BABIP_5'] = (team_games['b_hits_5'] - team_games['b_hr_5'])/(team_games['b_ab_5'] - team_games['b_strikeout_5'] - team_games['b_hr_5'] + team_games['b_sac_fly_5'])

team_games['b_xFIP_10'] = (13*(team_games['b_hr_10']) + 3*(team_games['b_walk_10'] + team_games['b_intentional_walk_10']) - 2*team_games['b_strikeout_10'])/(team_games['b_outs_10']/3)
team_games['b_wOBA_10'] = (.69*team_games['b_walk_10'] + .72*team_games['b_intentional_walk_10'] + .89*team_games['b_single_10'] + 1.27*team_games['b_double_10'] + 1.62*team_games['b_triple_10'] + 2.1*team_games['b_hr_10'])/(team_games['b_ab_10'] + team_games['b_walk_10'] - team_games['b_intentional_walk_10'] + team_games['b_sac_fly_10'] + team_games['b_hit_by_pitch_10'])
team_games['b_BABIP_10'] = (team_games['b_hits_10'] - team_games['b_hr_10'])/(team_games['b_ab_10'] - team_games['b_strikeout_10'] - team_games['b_hr_10'] + team_games['b_sac_fly_10'])

# %%
team_games['bat_ldr_5_diff'] = team_games['bat_ldr_c'] - team_games['bat_ldr_5']
team_games['bat_ldr_10_diff'] = team_games['bat_ldr_c'] - team_games['bat_ldr_10']

team_games['bat_gbr_5_diff'] = team_games['bat_gbr_c'] - team_games['bat_gbr_5']
team_games['bat_gbr_10_diff'] = team_games['bat_gbr_c'] - team_games['bat_gbr_10']

team_games['bat_fbr_5_diff'] = team_games['bat_fbr_c'] - team_games['bat_fbr_5']
team_games['bat_fbr_10_diff'] = team_games['bat_fbr_c'] - team_games['bat_fbr_10']

team_games['bat_hrfb_5_diff'] = team_games['bat_hr_fb_c'] - team_games['bat_hr_fb_5']
team_games['bat_hrfb_10_diff'] = team_games['bat_hr_fb_c'] - team_games['bat_hr_fb_10']

team_games['bat_xFIP_5_diff'] = team_games['bat_xFIP_c'] - team_games['bat_xFIP_5']
team_games['bat_xFIP_10_diff'] = team_games['bat_xFIP_c'] - team_games['bat_xFIP_10']

team_games['bat_wOBA_5_diff'] = team_games['bat_wOBA_c'] - team_games['bat_wOBA_5']
team_games['bat_wOBA_10_diff'] = team_games['bat_wOBA_c'] - team_games['bat_wOBA_10']

team_games['bat_BABIP_5_diff'] = team_games['bat_BABIP_c'] - team_games['bat_BABIP_5']
team_games['bat_BABIP_10_diff'] = team_games['bat_BABIP_c'] - team_games['bat_BABIP_10']

team_games['bat_kb_r_5_diff'] = team_games['bat_kb_r_c'] - team_games['bat_kb_r_5']
team_games['bat_kb_r_10_diff'] = team_games['bat_kb_r_c'] - team_games['bat_kb_r_10']

team_games['b_ldr_5_diff'] = team_games['b_ldr_c'] - team_games['b_ldr_5']
team_games['b_ldr_10_diff'] = team_games['b_ldr_c'] - team_games['b_ldr_10']

team_games['b_gbr_5_diff'] = team_games['b_gbr_c'] - team_games['b_gbr_5']
team_games['b_gbr_10_diff'] = team_games['b_gbr_c'] - team_games['b_gbr_10']

team_games['b_fbr_5_diff'] = team_games['b_fbr_c'] - team_games['b_fbr_5']
team_games['b_fbr_10_diff'] = team_games['b_fbr_c'] - team_games['b_fbr_10']

team_games['b_hrfb_5_diff'] = team_games['b_hr_fb_c'] - team_games['b_hr_fb_5']
team_games['b_hrfb_10_diff'] = team_games['b_hr_fb_c'] - team_games['b_hr_fb_10']

team_games['b_xFIP_5_diff'] = team_games['b_xFIP_c'] - team_games['b_xFIP_5']
team_games['b_xFIP_10_diff'] = team_games['b_xFIP_c'] - team_games['b_xFIP_10']

team_games['b_wOBA_5_diff'] = team_games['b_wOBA_c'] - team_games['b_wOBA_5']
team_games['b_wOBA_10_diff'] = team_games['b_wOBA_c'] - team_games['b_wOBA_10']

team_games['b_BABIP_5_diff'] = team_games['b_BABIP_c'] - team_games['b_BABIP_5']
team_games['b_BABIP_10_diff'] = team_games['b_BABIP_c'] - team_games['b_BABIP_10']

team_games['b_kb_r_5_diff'] = team_games['b_kb_r_c'] - team_games['b_kb_r_5']
team_games['b_kb_r_10_diff'] = team_games['b_kb_r_c'] - team_games['b_kb_r_10']


team_games['s_ldr_5_diff'] = team_games['s_ldr_c'] - team_games['s_ldr_5']
team_games['s_ldr_10_diff'] = team_games['s_ldr_c'] - team_games['s_ldr_10']

team_games['s_gbr_5_diff'] = team_games['s_gbr_c'] - team_games['s_gbr_5']
team_games['s_gbr_10_diff'] = team_games['s_gbr_c'] - team_games['s_gbr_10']

team_games['s_fbr_5_diff'] = team_games['s_fbr_c'] - team_games['s_fbr_5']
team_games['s_fbr_10_diff'] = team_games['s_fbr_c'] - team_games['s_fbr_10']

team_games['s_hrfb_5_diff'] = team_games['s_hr_fb_c'] - team_games['s_hr_fb_5']
team_games['s_hrfb_10_diff'] = team_games['s_hr_fb_c'] - team_games['s_hr_fb_10']

team_games['s_xFIP_5_diff'] = team_games['s_xFIP_c'] - team_games['s_xFIP_5']
team_games['s_xFIP_10_diff'] = team_games['s_xFIP_c'] - team_games['s_xFIP_10']

team_games['s_wOBA_5_diff'] = team_games['s_wOBA_c'] - team_games['s_wOBA_5']
team_games['s_wOBA_10_diff'] = team_games['s_wOBA_c'] - team_games['s_wOBA_10']

team_games['s_BABIP_5_diff'] = team_games['s_BABIP_c'] - team_games['s_BABIP_5']
team_games['s_BABIP_10_diff'] = team_games['s_BABIP_c'] - team_games['s_BABIP_10']

team_games['s_kb_r_5_diff'] = team_games['s_kb_r_c'] - team_games['s_kb_r_5']
team_games['s_kb_r_10_diff'] = team_games['s_kb_r_c'] - team_games['s_kb_r_10']

# %%
team_games = team_games[team_games['season'].astype(int) >= 2009]

# %%
team_games.columns.values
# Out:
# array(['date', 'game_id', 'team_id', 's_pitcher', 's_pitcher_hand',
#        's_starter', 's_earned_runs', 's_groundball', 's_flyball',
#        's_popup', 's_linedrive', 's_errors', 's_balls', 's_called_balls',
#        's_int_balls', 's_pitchout', 's_hit_batter', 's_other_balls',
#        's_strikes', 's_called_strikes', 's_swinging_strike',
#        's_foul_strike', 's_other_strikes', 's_unknown', 's_none',
#        's_generic_out', 's_strikeout', 's_stolen_base',
#        's_defensive_indifference', 's_caught_stealing', 's_pickoff_error',
#        's_pickoff', 's_wild_pitch', 's_passed_ball', 's_balk',
#        's_out_advancing', 's_foul_error', 's_walk', 's_intentional_walk',
#        's_hit_by_pitch', 's_interference', 's_error', 's_fielders_choice',
#        's_single', 's_double', 's_triple', 's_home_run', 's_missing_play',
#        's_outs', 's_sac_fly', 's_sac_hit', 's_ab', 'b_earned_runs',
#        'b_groundball', 'b_flyball', 'b_popup', 'b_linedrive', 'b_errors',
# ...

# %%
team_games['game_team'] = team_games['game_id'] + '-' + team_games['team_id']
team_games_condensed = team_games[['game_id', 'team_id', 'game_team', 's_pitcher', 
                                   's_pitcher_hand', 's_ab_5', 's_ab_10', 's_ldr_c', 's_ldr_5', 
                                   's_ldr_10', 's_gbr_c', 's_gbr_5', 's_gbr_10',
                                   's_fbr_c', 's_fbr_5', 's_fbr_10', 's_hr_fb_c', 
                                   's_hr_fb_5', 's_hr_fb_10','s_xFIP_c', 's_xFIP_5',
                                   's_xFIP_10', 's_wOBA_c', 's_wOBA_5','s_wOBA_10',
                                   's_BABIP_c', 's_BABIP_5', 's_BABIP_10','s_kb_r_c',
                                   's_kb_r_5', 's_kb_r_10',  'b_ab_5', 'b_ab_10', 
                                   'b_ldr_c', 'b_ldr_5', 'b_ldr_10', 'b_gbr_c', 
                                   'b_gbr_5','b_gbr_10', 'b_fbr_c', 'b_fbr_5', 
                                   'b_fbr_10', 'b_hr_fb_c', 'b_hr_fb_5','b_hr_fb_10',
                                   'b_xFIP_c', 'b_xFIP_5', 'b_xFIP_10','b_wOBA_c', 
                                   'b_wOBA_5', 'b_wOBA_10', 'b_BABIP_c', 'b_BABIP_5',
                                   'b_BABIP_10', 'b_kb_r_c', 'b_kb_r_5', 'b_kb_r_10',
                                   'bat_ab_5', 'bat_ab_10', 'bat_ldr_c', 'bat_ldr_5', 
                                   'bat_ldr_10', 'bat_gbr_c', 'bat_gbr_5','bat_gbr_10',
                                   'bat_fbr_c', 'bat_fbr_5', 'bat_fbr_10','bat_hr_fb_c',
                                   'bat_hr_fb_5', 'bat_hr_fb_10', 'bat_xFIP_c', 'bat_xFIP_5',
                                   'bat_xFIP_10', 'bat_wOBA_c', 'bat_wOBA_5', 'bat_wOBA_10',
                                   'bat_BABIP_c', 'bat_BABIP_5', 'bat_BABIP_10', 'bat_kb_r_c', 
                                   'bat_kb_r_5','bat_kb_r_10']]
team_games_condensed
# Out:
# C:\Users\mendo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             game_id team_id         game_team s_pitcher s_pitcher_hand  \
# 9479   PHI200904050     ATL  PHI200904050-ATL  lowed001              R
# 9480   PHI200904050     PHI  PHI200904050-PHI  myerb001              R
# 9481   ANA200904060     ANA  ANA200904060-ANA  saunj001              L
# 9482   ANA200904060     OAK  ANA200904060-OAK  bradd002              L
# 9483   ARI200904060     ARI  ARI200904060-ARI  webbb001              R
# 9484   ARI200904060     COL  ARI200904060-COL  cooka002              R
# 9485   BAL200904060     BAL  BAL200904060-BAL  guthj001              R
# ...

# %%
ht = team_games_condensed[['game_id', 'team_id']]
ht['home_'] = ht['game_id'].str[0:3]
ht = ht[['game_id', 'home_']].drop_duplicates()
# Out:
# C:\Users\mendo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
team_games_condensed = team_games_condensed.merge(ht, how='left', on='game_id')
team_games_condensed['home_'] = team_games_condensed['team_id'] == team_games_condensed['home_']
team_games_condensed
# Out:
#             game_id team_id         game_team s_pitcher s_pitcher_hand  \
# 0      PHI200904050     ATL  PHI200904050-ATL  lowed001              R
# 1      PHI200904050     PHI  PHI200904050-PHI  myerb001              R
# 2      ANA200904060     ANA  ANA200904060-ANA  saunj001              L
# 3      ANA200904060     OAK  ANA200904060-OAK  bradd002              L
# 4      ARI200904060     ARI  ARI200904060-ARI  webbb001              R
# 5      ARI200904060     COL  ARI200904060-COL  cooka002              R
# 6      BAL200904060     BAL  BAL200904060-BAL  guthj001              R
# 7      BAL200904060     NYA  BAL200904060-NYA  sabac001              L
# 8      CIN200904060     CIN  CIN200904060-CIN  haraa001              R
# 9      CIN200904060     NYN  CIN200904060-NYN  santj003              L
# 10     FLO200904060     FLO  FLO200904060-FLO  nolar001              R
# 11     FLO200904060     WAS  FLO200904060-WAS  lannj001              L
# ...

# %%
t_home= team_games_condensed[team_games_condensed['home_']==True]
t_vis= team_games_condensed[team_games_condensed['home_']==False]

t_home.columns = ['home_' + str(col) for col in t_home.columns]
t_vis.columns = ['vis_' + str(col) for col in t_vis.columns]

# %%
tg = t_home.merge(t_vis, how='left', left_on='home_game_id', right_on='vis_game_id')
tg
# Out:
#        home_game_id home_team_id    home_game_team home_s_pitcher  \
# 0      PHI200904050          PHI  PHI200904050-PHI       myerb001
# 1      ANA200904060          ANA  ANA200904060-ANA       saunj001
# 2      ARI200904060          ARI  ARI200904060-ARI       webbb001
# 3      BAL200904060          BAL  BAL200904060-BAL       guthj001
# 4      CIN200904060          CIN  CIN200904060-CIN       haraa001
# 5      FLO200904060          FLO  FLO200904060-FLO       nolar001
# 6      HOU200904060          HOU  HOU200904060-HOU       oswar001
# 7      MIN200904060          MIN  MIN200904060-MIN       lirif001
# 8      SDN200904060          SDN  SDN200904060-SDN       peavj001
# 9      SLN200904060          SLN  SLN200904060-SLN       waina001
# 10     TEX200904060          TEX  TEX200904060-TEX       millk004
# 11     TOR200904060          TOR  TOR200904060-TOR       hallr001
# 12     ANA200904070          ANA  ANA200904070-ANA       mosed001
# ...

# %%
tg = tg[['home_game_id', 'home_s_pitcher',
         'home_s_pitcher_hand', 'home_s_ab_5', 'home_s_ab_10',
         'home_s_ldr_c', 'home_s_ldr_5', 'home_s_ldr_10',
         'home_s_gbr_c', 'home_s_gbr_5', 'home_s_gbr_10',
         'home_s_fbr_c', 'home_s_fbr_5', 'home_s_fbr_10',
         'home_s_hr_fb_c', 'home_s_hr_fb_5', 'home_s_hr_fb_10',
         'home_s_xFIP_c', 'home_s_xFIP_5', 'home_s_xFIP_10',
         'home_s_wOBA_c', 'home_s_wOBA_5', 'home_s_wOBA_10',
         'home_s_BABIP_c', 'home_s_BABIP_5', 'home_s_BABIP_10',
         'home_s_kb_r_c', 'home_s_kb_r_5', 'home_s_kb_r_10',
         'home_b_ab_5', 'home_b_ab_10', 'home_b_ldr_c', 'home_b_ldr_5',
         'home_b_ldr_10', 'home_b_gbr_c', 'home_b_gbr_5',
         'home_b_gbr_10', 'home_b_fbr_c', 'home_b_fbr_5',
         'home_b_fbr_10', 'home_b_hr_fb_c', 'home_b_hr_fb_5',
         'home_b_hr_fb_10', 'home_b_xFIP_c', 'home_b_xFIP_5',
         'home_b_xFIP_10', 'home_b_wOBA_c', 'home_b_wOBA_5',
         'home_b_wOBA_10', 'home_b_BABIP_c', 'home_b_BABIP_5',
         'home_b_BABIP_10', 'home_b_kb_r_c', 'home_b_kb_r_5',
         'home_b_kb_r_10', 'home_bat_ab_5', 'home_bat_ab_10',
         'home_bat_ldr_c', 'home_bat_ldr_5', 'home_bat_ldr_10',
         'home_bat_gbr_c', 'home_bat_gbr_5', 'home_bat_gbr_10',
         'home_bat_fbr_c', 'home_bat_fbr_5', 'home_bat_fbr_10',
         'home_bat_hr_fb_c', 'home_bat_hr_fb_5', 'home_bat_hr_fb_10',
         'home_bat_xFIP_c', 'home_bat_xFIP_5', 'home_bat_xFIP_10',
         'home_bat_wOBA_c', 'home_bat_wOBA_5', 'home_bat_wOBA_10',
         'home_bat_BABIP_c', 'home_bat_BABIP_5',
         'home_bat_BABIP_10', 'home_bat_kb_r_c', 'home_bat_kb_r_5',
         'home_bat_kb_r_10', 'vis_s_pitcher', 'vis_s_pitcher_hand', 
         'vis_s_ab_5', 'vis_s_ab_10',
         'vis_s_ldr_c', 'vis_s_ldr_5', 'vis_s_ldr_10',
         'vis_s_gbr_c', 'vis_s_gbr_5', 'vis_s_gbr_10',
         'vis_s_fbr_c', 'vis_s_fbr_5', 'vis_s_fbr_10',
         'vis_s_hr_fb_c', 'vis_s_hr_fb_5', 'vis_s_hr_fb_10',
         'vis_s_xFIP_c', 'vis_s_xFIP_5', 'vis_s_xFIP_10',
         'vis_s_wOBA_c', 'vis_s_wOBA_5', 'vis_s_wOBA_10',
         'vis_s_BABIP_c', 'vis_s_BABIP_5', 'vis_s_BABIP_10',
         'vis_s_kb_r_c', 'vis_s_kb_r_5', 'vis_s_kb_r_10',
         'vis_b_ab_5', 'vis_b_ab_10', 'vis_b_ldr_c', 'vis_b_ldr_5',
         'vis_b_ldr_10', 'vis_b_gbr_c', 'vis_b_gbr_5',
         'vis_b_gbr_10', 'vis_b_fbr_c', 'vis_b_fbr_5',
         'vis_b_fbr_10', 'vis_b_hr_fb_c', 'vis_b_hr_fb_5',
         'vis_b_hr_fb_10', 'vis_b_xFIP_c', 'vis_b_xFIP_5',
         'vis_b_xFIP_10', 'vis_b_wOBA_c', 'vis_b_wOBA_5',
         'vis_b_wOBA_10', 'vis_b_BABIP_c', 'vis_b_BABIP_5',
         'vis_b_BABIP_10', 'vis_b_kb_r_c', 'vis_b_kb_r_5',
         'vis_b_kb_r_10', 'vis_bat_ab_5', 'vis_bat_ab_10',
         'vis_bat_ldr_c', 'vis_bat_ldr_5', 'vis_bat_ldr_10',
         'vis_bat_gbr_c', 'vis_bat_gbr_5', 'vis_bat_gbr_10',
         'vis_bat_fbr_c', 'vis_bat_fbr_5', 'vis_bat_fbr_10',
         'vis_bat_hr_fb_c', 'vis_bat_hr_fb_5', 'vis_bat_hr_fb_10',
         'vis_bat_xFIP_c', 'vis_bat_xFIP_5', 'vis_bat_xFIP_10',
         'vis_bat_wOBA_c', 'vis_bat_wOBA_5', 'vis_bat_wOBA_10',
         'vis_bat_BABIP_c', 'vis_bat_BABIP_5', 'vis_bat_BABIP_10',
         'vis_bat_kb_r_c', 'vis_bat_kb_r_5', 'vis_bat_kb_r_10']]

# %%
tg.columns = ['game_id', 'home_s_pitcher',
              'home_s_pitcher_hand', 'home_s_ab_5', 'home_s_ab_10',
              'home_s_ldr_c', 'home_s_ldr_5', 'home_s_ldr_10',
              'home_s_gbr_c', 'home_s_gbr_5', 'home_s_gbr_10',
              'home_s_fbr_c', 'home_s_fbr_5', 'home_s_fbr_10',
              'home_s_hr_fb_c', 'home_s_hrfb_5', 'home_s_hrfb_10',
              'home_s_xFIP_c', 'home_s_xFIP_5', 'home_s_xFIP_10',
              'home_s_wOBA_c', 'home_s_wOBA_5', 'home_s_wOBA_10',
              'home_s_BABIP_c', 'home_s_BABIP_5', 'home_s_BABIP_10',
              'home_s_kb_r_c', 'home_s_kb_r_5', 'home_s_kb_r_10',
              'home_b_ab_5', 'home_b_ab_10', 'home_b_ldr_c', 'home_b_ldr_5',
              'home_b_ldr_10', 'home_b_gbr_c', 'home_b_gbr_5',
              'home_b_gbr_10', 'home_b_fbr_c', 'home_b_fbr_5',
              'home_b_fbr_10', 'home_b_hr_fb_c', 'home_b_hrfb_5',
              'home_b_hrfb_10', 'home_b_xFIP_c', 'home_b_xFIP_5',
              'home_b_xFIP_10', 'home_b_wOBA_c', 'home_b_wOBA_5',
              'home_b_wOBA_10', 'home_b_BABIP_c', 'home_b_BABIP_5',
              'home_b_BABIP_10', 'home_b_kb_r_c', 'home_b_kb_r_5',
              'home_b_kb_r_10', 'home_bat_ab_5', 'home_bat_ab_10',
              'home_bat_ldr_c', 'home_bat_ldr_5', 'home_bat_ldr_10',
              'home_bat_gbr_c', 'home_bat_gbr_5', 'home_bat_gbr_10',
              'home_bat_fbr_c', 'home_bat_fbr_5', 'home_bat_fbr_10',
              'home_bat_hr_fb_c', 'home_bat_hrfb_5', 'home_bat_hrfb_10',
              'home_bat_xFIP_c', 'home_bat_xFIP_5', 'home_bat_xFIP_10',
              'home_bat_wOBA_c', 'home_bat_wOBA_5', 'home_bat_wOBA_10',
              'home_bat_BABIP_c', 'home_bat_BABIP_5',
              'home_bat_BABIP_10', 'home_bat_kb_r_c', 'home_bat_kb_r_5',
              'home_bat_kb_r_10', 'vis_s_pitcher', 'vis_s_pitcher_hand', 
              'vis_s_ab_5', 'vis_s_ab_10',
              'vis_s_ldr_c', 'vis_s_ldr_5', 'vis_s_ldr_10',
              'vis_s_gbr_c', 'vis_s_gbr_5', 'vis_s_gbr_10',
              'vis_s_fbr_c', 'vis_s_fbr_5', 'vis_s_fbr_10',
              'vis_s_hr_fb_c', 'vis_s_hrfb_5', 'vis_s_hrfb_10',
              'vis_s_xFIP_c', 'vis_s_xFIP_5', 'vis_s_xFIP_10',
              'vis_s_wOBA_c', 'vis_s_wOBA_5', 'vis_s_wOBA_10',
              'vis_s_BABIP_c', 'vis_s_BABIP_5', 'vis_s_BABIP_10',
              'vis_s_kb_r_c', 'vis_s_kb_r_5', 'vis_s_kb_r_10',
              'vis_b_ab_5', 'vis_b_ab_10', 'vis_b_ldr_c', 'vis_b_ldr_5',
              'vis_b_ldr_10', 'vis_b_gbr_c', 'vis_b_gbr_5',
              'vis_b_gbr_10', 'vis_b_fbr_c', 'vis_b_fbr_5',
              'vis_b_fbr_10', 'vis_b_hr_fb_c', 'vis_b_hrfb_5',
              'vis_b_hrfb_10', 'vis_b_xFIP_c', 'vis_b_xFIP_5',
              'vis_b_xFIP_10', 'vis_b_wOBA_c', 'vis_b_wOBA_5',
              'vis_b_wOBA_10', 'vis_b_BABIP_c', 'vis_b_BABIP_5',
              'vis_b_BABIP_10', 'vis_b_kb_r_c', 'vis_b_kb_r_5',
              'vis_b_kb_r_10', 'vis_bat_ab_5', 'vis_bat_ab_10',
              'vis_bat_ldr_c', 'vis_bat_ldr_5', 'vis_bat_ldr_10',
              'vis_bat_gbr_c', 'vis_bat_gbr_5', 'vis_bat_gbr_10',
              'vis_bat_fbr_c', 'vis_bat_fbr_5', 'vis_bat_fbr_10',
              'vis_bat_hr_fb_c', 'vis_bat_hrfb_5', 'vis_bat_hrfb_10',
              'vis_bat_xFIP_c', 'vis_bat_xFIP_5', 'vis_bat_xFIP_10',
              'vis_bat_wOBA_c', 'vis_bat_wOBA_5', 'vis_bat_wOBA_10',
              'vis_bat_BABIP_c', 'vis_bat_BABIP_5', 'vis_bat_BABIP_10',
              'vis_bat_kb_r_c', 'vis_bat_kb_r_5', 'vis_bat_kb_r_10']

# %%
import numpy as np
tg = tg.replace([np.inf, -np.inf], np.nan)
tg = tg.fillna(0)

# %%
tg
# Out:
#             game_id home_s_pitcher home_s_pitcher_hand  home_s_ab_5  \
# 0      PHI200904050       myerb001                   R          0.0
# 1      ANA200904060       saunj001                   L          0.0
# 2      ARI200904060       webbb001                   R          0.0
# 3      BAL200904060       guthj001                   R          0.0
# 4      CIN200904060       haraa001                   R          0.0
# 5      FLO200904060       nolar001                   R          0.0
# 6      HOU200904060       oswar001                   R          0.0
# 7      MIN200904060       lirif001                   L          0.0
# 8      SDN200904060       peavj001                   R          0.0
# 9      SLN200904060       waina001                   R          0.0
# 10     TEX200904060       millk004                   R          0.0
# 11     TOR200904060       hallr001                   R          0.0
# 12     ANA200904070       mosed001                   R          0.0
# ...

# %%
tg['m_ldr_def'] = (tg['home_s_ldr_c'] + tg['home_b_ldr_c'])/2 - tg['vis_bat_ldr_c']
tg['m_ldr_off'] = tg['home_bat_ldr_c'] - (tg['vis_s_ldr_c'] + tg['vis_b_ldr_c'])/2

tg['m_gbr_def'] = (tg['home_s_gbr_c'] + tg['home_b_gbr_c'])/2 - tg['vis_bat_gbr_c']
tg['m_gbr_off'] = tg['home_bat_gbr_c'] - (tg['vis_s_gbr_c'] + tg['vis_b_gbr_c'])/2

tg['m_hrfb_def'] = (tg['home_s_hr_fb_c'] + tg['home_b_hr_fb_c'])/2 - tg['vis_bat_hr_fb_c']
tg['m_ldr_off'] = tg['home_bat_hr_fb_c'] - (tg['vis_s_hr_fb_c'] + tg['vis_b_hr_fb_c'])/2

tg['m_xFIP_def'] = (tg['home_s_xFIP_c'] + tg['home_b_xFIP_c'])/2 - tg['vis_bat_xFIP_c']
tg['m_xFIP_off'] = tg['home_bat_xFIP_c'] - (tg['vis_s_xFIP_c'] + tg['vis_b_xFIP_c'])/2

tg['m_wOBA_def'] = (tg['home_s_wOBA_c'] + tg['home_b_wOBA_c'])/2 - tg['vis_bat_wOBA_c']
tg['m_wOBA_off'] = tg['home_bat_wOBA_c'] - (tg['vis_s_wOBA_c'] + tg['vis_b_wOBA_c'])/2

tg['m_BABIP_def'] = (tg['home_s_BABIP_c'] + tg['home_b_BABIP_c'])/2 - tg['vis_bat_BABIP_c']
tg['m_BABIP_off'] = tg['home_bat_BABIP_c'] - (tg['vis_s_BABIP_c'] + tg['vis_b_BABIP_c'])/2

tg['m_kbr_def'] = (tg['home_s_kb_r_c'] + tg['home_b_kb_r_c'])/2 - tg['vis_bat_kb_r_c']
tg['m_kbr_off'] = tg['home_bat_kb_r_c'] - (tg['vis_s_kb_r_c'] + tg['vis_b_kb_r_c'])/2



tg['m_ldr_def_5'] = (tg['home_s_ldr_c'] + tg['home_b_ldr_5'])/2 - tg['vis_bat_ldr_5']
tg['m_ldr_off_5'] = tg['home_bat_ldr_5'] - (tg['vis_s_ldr_c'] + tg['vis_b_ldr_5'])/2

tg['m_gbr_def_5'] = (tg['home_s_gbr_c'] + tg['home_b_gbr_5'])/2 - tg['vis_bat_gbr_5']
tg['m_gbr_off_5'] = tg['home_bat_gbr_5'] - (tg['vis_s_gbr_c'] + tg['vis_b_gbr_5'])/2

tg['m_hrfb_def_5'] = (tg['home_s_hr_fb_c'] + tg['home_b_hrfb_5'])/2 - tg['vis_bat_hrfb_5']
tg['m_ldr_off_5'] = tg['home_bat_hrfb_5'] - (tg['vis_s_hr_fb_c'] + tg['vis_b_hrfb_5'])/2

tg['m_xFIP_def_5'] = (tg['home_s_xFIP_c'] + tg['home_b_xFIP_5'])/2 - tg['vis_bat_xFIP_5']
tg['m_xFIP_off_5'] = tg['home_bat_xFIP_5'] - (tg['vis_s_xFIP_c'] + tg['vis_b_xFIP_5'])/2

tg['m_wOBA_def_5'] = (tg['home_s_wOBA_c'] + tg['home_b_wOBA_5'])/2 - tg['vis_bat_wOBA_5']
tg['m_wOBA_off_5'] = tg['home_bat_wOBA_5'] - (tg['vis_s_wOBA_c'] + tg['vis_b_wOBA_5'])/2

tg['m_BABIP_def_5'] = (tg['home_s_BABIP_c'] + tg['home_b_BABIP_5'])/2 - tg['vis_bat_BABIP_5']
tg['m_BABIP_off_5'] = tg['home_bat_BABIP_5'] - (tg['vis_s_BABIP_c'] + tg['vis_b_BABIP_5'])/2

tg['m_kbr_def_5'] = (tg['home_s_kb_r_c'] + tg['home_b_kb_r_5'])/2 - tg['vis_bat_kb_r_5']
tg['m_kbr_off_5'] = tg['home_bat_kb_r_5'] - (tg['vis_s_kb_r_c'] + tg['vis_b_kb_r_5'])/2



tg['m_ldr_def_10'] = (tg['home_s_ldr_c'] + tg['home_b_ldr_10'])/2 - tg['vis_bat_ldr_10']
tg['m_ldr_off_10'] = tg['home_bat_ldr_10'] - (tg['vis_s_ldr_c'] + tg['vis_b_ldr_10'])/2

tg['m_gbr_def_10'] = (tg['home_s_gbr_c'] + tg['home_b_gbr_10'])/2 - tg['vis_bat_gbr_10']
tg['m_gbr_off_10'] = tg['home_bat_gbr_10'] - (tg['vis_s_gbr_c'] + tg['vis_b_gbr_10'])/2

tg['m_hrfb_def_10'] = (tg['home_s_hr_fb_c'] + tg['home_b_hrfb_10'])/2 - tg['vis_bat_hrfb_10']
tg['m_ldr_off_10'] = tg['home_bat_hrfb_10'] - (tg['vis_s_hr_fb_c'] + tg['vis_b_hrfb_10'])/2

tg['m_xFIP_def_10'] = (tg['home_s_xFIP_c'] + tg['home_b_xFIP_10'])/2 - tg['vis_bat_xFIP_10']
tg['m_xFIP_off_10'] = tg['home_bat_xFIP_10'] - (tg['vis_s_xFIP_c'] + tg['vis_b_xFIP_10'])/2

tg['m_wOBA_def_10'] = (tg['home_s_wOBA_c'] + tg['home_b_wOBA_10'])/2 - tg['vis_bat_wOBA_10']
tg['m_wOBA_off_10'] = tg['home_bat_wOBA_10'] - (tg['vis_s_wOBA_c'] + tg['vis_b_wOBA_10'])/2

tg['m_BABIP_def_10'] = (tg['home_s_BABIP_c'] + tg['home_b_BABIP_10'])/2 - tg['vis_bat_BABIP_10']
tg['m_BABIP_off_10'] = tg['home_bat_BABIP_10'] - (tg['vis_s_BABIP_c'] + tg['vis_b_BABIP_10'])/2

tg['m_kbr_def_10'] = (tg['home_s_kb_r_c'] + tg['home_b_kb_r_10'])/2 - tg['vis_bat_kb_r_10']
tg['m_kbr_off_10'] = tg['home_bat_kb_r_10'] - (tg['vis_s_kb_r_c'] + tg['vis_b_kb_r_10'])/2

# %%
tg.columns.values
# Out:
# array(['game_id', 'home_s_pitcher', 'home_s_pitcher_hand', 'home_s_ab_5',
#        'home_s_ab_10', 'home_s_ldr_c', 'home_s_ldr_5', 'home_s_ldr_10',
#        'home_s_gbr_c', 'home_s_gbr_5', 'home_s_gbr_10', 'home_s_fbr_c',
#        'home_s_fbr_5', 'home_s_fbr_10', 'home_s_hr_fb_c', 'home_s_hrfb_5',
#        'home_s_hrfb_10', 'home_s_xFIP_c', 'home_s_xFIP_5',
#        'home_s_xFIP_10', 'home_s_wOBA_c', 'home_s_wOBA_5',
#        'home_s_wOBA_10', 'home_s_BABIP_c', 'home_s_BABIP_5',
#        'home_s_BABIP_10', 'home_s_kb_r_c', 'home_s_kb_r_5',
#        'home_s_kb_r_10', 'home_b_ab_5', 'home_b_ab_10', 'home_b_ldr_c',
#        'home_b_ldr_5', 'home_b_ldr_10', 'home_b_gbr_c', 'home_b_gbr_5',
#        'home_b_gbr_10', 'home_b_fbr_c', 'home_b_fbr_5', 'home_b_fbr_10',
#        'home_b_hr_fb_c', 'home_b_hrfb_5', 'home_b_hrfb_10',
#        'home_b_xFIP_c', 'home_b_xFIP_5', 'home_b_xFIP_10', 'home_b_wOBA_c',
#        'home_b_wOBA_5', 'home_b_wOBA_10', 'home_b_BABIP_c',
# ...

# %%
df = tg

# %%
df.describe()
# Out:
#         home_s_ab_5  home_s_ab_10  home_s_ldr_c  home_s_ldr_5  home_s_ldr_10  \
# count  21376.000000  21376.000000  21376.000000  21376.000000   21376.000000
# mean     123.352124    238.692412      0.207492      0.210747       0.198311
# std       24.502262     64.005006      0.044255      0.078054       0.083387
# min        0.000000      0.000000      0.000000      0.000000       0.000000
# 25%      120.000000    242.000000      0.187376      0.174419       0.173267
# 50%      128.000000    255.000000      0.204516      0.216495       0.212887
# 75%      134.000000    265.000000      0.227075      0.260870       0.251582
# max      162.000000    307.000000      0.833333      0.509804       0.419355
#
#        home_s_gbr_c  home_s_gbr_5  home_s_gbr_10  home_s_fbr_c  home_s_fbr_5  \
# count  21376.000000  21376.000000   21376.000000  21376.000000  21376.000000
# mean       0.448963      0.429033       0.407585      0.256804      0.231505
# ...

# %%
df.to_csv(r'C:\\Users\\mendo\\Desktop\\team_stats.csv', sep=',')
